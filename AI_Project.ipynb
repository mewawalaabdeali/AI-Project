# %% [markdown]
# # **Sign Language Recognition using Deep Learning: MNIST Dataset Analysis**
# ![Sign_Language_Image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Abstract**:
# Sign language is a crucial means of communication for individuals with hearing impairments. In this project:
#
#
# * We aim to develop a fully functional AI system using deep learning techniques,
# specifically neural networks, to recognize hand gestures corresponding to American Sign Language (ASL) alphabets.
# * Using the Sign Language MNIST dataset, we will conduct Exploratory Data Analysis (EDA), preprocess the data, and train a classification model to accurately identify different hand signs.
# * This project aims to enhance accessibility and communication by leveraging state-of-the-art deep learning models for sign language recognition.

# %% [markdown]
# # **Problem Statement:**
# People with hearing impairments primarily rely on sign language for communication. However, many individuals are unfamiliar with sign language, creating a barrier between the deaf and hearing communities. Traditional text-based communication methods are often ineffective in real-time conversations.
#
# The Sign Language MNIST dataset provides an opportunity to train a deep learning model using neural networks to recognize ASL alphabets from hand gesture images. This project aims to develop an AI-powered system that accurately interprets sign language symbols and translates them into readable text. By leveraging Convolutional Neural Networks (CNNs) and other deep learning techniques, we aim to create a robust model that enhances accessibility and inclusivity for individuals with hearing impairments.

# %% [markdown]
# ## **Objectives**:
#
#
# 1.   Develop a Sign Language Recognition System – Train a deep learning model using neural networks to classify hand signs representing ASL alphabets.
#
# 1.   Perform Exploratory Data Analysis (EDA) – Analyze the dataset to understand its structure, distribution, and potential challenges before training the model.
#
# 1.   Preprocess and Augment Data – Apply necessary transformations, such as normalization, resizing, and augmentation, to enhance model performance and generalization.
# 2.   Train and Evaluate Deep Learning Models – Experiment with different neural network architectures (e.g., Convolutional Neural Networks - CNNs) to achieve high accuracy.
#
# 1.   Optimize and Fine-Tune the Model – Use techniques such as hyperparameter tuning, dropout, and batch normalization to improve the model's efficiency and robustness.

# %% [markdown]
# # **Name and Source of Dataset**
# Dataset Name: Sign Language MNIST
#
# Source: https://www.kaggle.com/datasets/datamunge/sign-language-mnist/data/
#
# Description: The dataset contains images of hand signs corresponding to the
# American Sign Language (ASL) alphabets, specifically A to Y (excluding J and Z, as they require motion).

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**
#
#       We'll analyze the dataset to understand:
#         1.   Understanding the dataset and its shape
#         2.   Checking the type of data and each column
#         3.   Categorical and Numerical Columns
#         4.   Checking for missing values and inconsistencies
#         5.   Descriptive summary of the dataset
#         6.   Groupby for classification problem
#         7.   The distribution of images across classes
#         8.   Sample images for visualization

# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
#loading the training dataset from csv file to pandas data frame
train_data = pd.read_csv('/content/sign_mnist_train.csv')

# %%
#printing the first five rows of the dataframe
train_data.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...     207.0     207.0     207.0     207.0     206.0     206.0
# 1     158  ...      69.0     149.0     128.0      87.0      94.0     163.0
# 2     187  ...     202.0     201.0     200.0     199.0     198.0     199.0
# 3     210  ...     235.0     234.0     233.0     231.0     230.0     226.0
# 4     185  ...      92.0     105.0     105.0     108.0     133.0     163.0
#
#    pixel781  pixel782  pixel783  pixel784
# 0     206.0     204.0     203.0     202.0
# 1     175.0     103.0     135.0     149.0
# 2     198.0     195.0     194.0     195.0
# 3     225.0     222.0     229.0     163.0
# 4     157.0     163.0     164.0     179.0
#
# [5 rows x 785 columns]

# %%
train_data.shape
# Out:
# (7944, 785)

# %%
#checking the datatypes
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7944 entries, 0 to 7943
# Columns: 785 entries, label to pixel784
# dtypes: float64(56), int64(729)
# memory usage: 47.6 MB

# %%
train_data.isnull().sum()
# Out:
# label       0
# pixel1      0
# pixel2      0
# pixel3      0
# pixel4      0
#            ..
# pixel780    1
# pixel781    1
# pixel782    1
# pixel783    1
# pixel784    1
# Length: 785, dtype: int64

# %%
missing_values=train_data.isnull().sum().sum()
print("Total Missing Values in Dataset:", missing_values)
# Out:
# Total Missing Values in Dataset: 56

# %%
train_data.describe()
# Out:
#              label       pixel1       pixel2       pixel3       pixel4  \
# count  7944.000000  7944.000000  7944.000000  7944.000000  7944.000000
# mean     12.235146   146.254406   149.332704   152.140987   154.387966
# std       7.301761    41.591206    40.130854    39.115021    38.612513
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       6.000000   122.000000   126.000000   131.000000   134.000000
# 50%      13.000000   151.000000   154.000000   156.000000   159.000000
# 75%      19.000000   175.000000   177.000000   179.000000   180.000000
# max      24.000000   255.000000   255.000000   255.000000   255.000000
#
#             pixel5       pixel6       pixel7       pixel8       pixel9  ...  \
# count  7944.000000  7944.000000  7944.000000  7944.000000  7944.000000  ...
# mean    156.900554   159.154834   161.223061   163.035624   164.650932  ...
# std      37.328899    36.161164    35.001927    33.827310    32.760560  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     137.750000   140.000000   143.000000   145.000000   147.000000  ...
# 50%     160.000000   162.000000   164.000000   166.000000   166.500000  ...
# 75%     181.000000   182.000000   183.000000   185.000000   185.000000  ...
# max     255.000000   255.000000   255.000000   255.000000   255.000000  ...
#
#           pixel775    pixel776     pixel777     pixel778     pixel779  \
# count  7943.000000  7943.00000  7943.000000  7943.000000  7943.000000
# mean    142.861639   148.95858   154.762936   160.193630   163.072517
# std      63.774694    65.02571    63.534302    62.988027    62.880754
# min       0.000000     0.00000     0.000000     0.000000     0.000000
# 25%      93.000000    97.00000   105.000000   114.000000   123.000000
# 50%     147.000000   164.00000   174.000000   181.000000   184.000000
# 75%     198.000000   203.00000   205.000000   207.000000   208.000000
# max     255.000000   255.00000   255.000000   255.000000   255.000000
#
#           pixel780     pixel781     pixel782     pixel783     pixel784
# count  7943.000000  7943.000000  7943.000000  7943.000000  7943.000000
# mean    163.836586   163.968652   162.905451   161.964245   160.852197
# std      62.588343    62.724176    62.436060    62.785132    63.380706
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     128.000000   131.000000   131.000000   131.000000   129.000000
# 50%     184.000000   184.000000   183.000000   182.000000   182.000000
# 75%     208.000000   207.000000   206.000000   205.000000   204.000000
# max     255.000000   255.000000   255.000000   255.000000   255.000000
#
# [8 rows x 785 columns]

# %%
train_data['label'].value_counts()
# Out:
# label
# 17    374
# 16    368
# 3     357
# 11    357
# 14    356
# 19    353
# 18    350
# 8     344
# 23    339
# 0     338
# 2     338
# 5     337
# 13    334
# 22    332
# 21    330
# 20    330
# 6     329
# 10    309
# 24    306
# 15    302
# 1     298
# 7     297
# 12    287
# 4     279
# Name: count, dtype: int64

# %%
train_data.groupby('label').mean()
# Out:
#            pixel1      pixel2      pixel3      pixel4      pixel5      pixel6  \
# label
# 0      164.497041  165.724852  163.059172  161.366864  164.455621  166.724852
# 1      144.456376  147.583893  150.375839  153.023490  154.234899  157.030201
# 2      160.470414  162.896450  165.316568  167.127219  168.508876  169.656805
# 3      137.910364  141.750700  144.977591  149.761905  153.532213  156.700280
# 4      165.258065  167.197133  168.982079  170.555556  172.100358  173.448029
# 5      141.130564  145.071217  148.709199  151.691395  154.581602  157.359050
# 6      174.838906  176.270517  177.659574  179.200608  180.401216  181.340426
# 7      165.851852  168.077441  170.265993  172.265993  173.734007  174.898990
# 8      161.956395  164.197674  166.770349  168.514535  170.337209  171.822674
# 10      96.514563  103.080906  104.288026  103.249191  107.067961  111.236246
# 11     144.215686  148.226891  151.725490  154.512605  156.767507  158.977591
# 12     154.104530  157.383275  160.773519  163.487805  166.041812  168.522648
# 13     155.443114  159.074850  162.056886  164.808383  167.652695  169.823353
# 14     161.811798  163.901685  165.682584  167.168539  168.446629  169.581461
# 15     112.453642  111.854305  115.887417  115.996689  118.748344  120.668874
# 16     120.410326  122.692935  128.097826  131.179348  133.467391  137.184783
# 17     136.564171  140.326203  144.318182  147.970588  151.237968  154.090909
# 18     153.420000  156.014286  158.222857  160.737143  163.214286  165.454286
# 19     167.467422  169.314448  171.201133  172.776204  174.002833  174.909348
# 20     135.396970  138.381818  141.672727  144.581818  147.812121  150.630303
# 21     143.066667  148.315152  152.660606  156.336364  159.372727  162.181818
# 22     123.292169  127.129518  131.750000  135.671687  140.692771  142.948795
# 23     143.687316  149.371681  152.902655  155.578171  158.185841  160.454277
# 24     146.431373  150.486928  154.006536  157.000000  160.078431  163.016340
#
#            pixel7      pixel8      pixel9     pixel10  ...    pixel775  \
# label                                                  ...
# 0      167.822485  168.884615  169.831361  170.677515  ...  157.600592
# 1      158.936242  160.318792  162.100671  163.610738  ...  117.332215
# 2      170.482249  170.961538  171.408284  171.710059  ...  205.639053
# 3      159.112045  161.148459  162.896359  164.047619  ...  107.095238
# 4      174.465950  175.222222  176.129032  176.835125  ...  112.057348
# 5      159.445104  161.154303  162.777448  164.074184  ...  159.525223
# 6      182.094225  182.580547  183.112462  183.303951  ...  142.860182
# 7      175.744108  176.717172  177.670034  178.289562  ...  157.912458
# 8      173.078488  173.668605  174.389535  173.883721  ...  160.223837
# 10     114.763754  117.475728  121.750809  127.207120  ...  121.766990
# 11     160.890756  162.249300  163.647059  164.913165  ...  169.759104
# 12     170.540070  171.961672  173.320557  174.599303  ...  132.912892
# 13     171.757485  173.676647  175.203593  176.389222  ...  126.215569
# 14     170.842697  171.969101  172.705056  173.261236  ...  176.584270
# 15     123.956954  126.913907  128.668874  133.145695  ...  110.400662
# 16     140.793478  145.130435  149.078804  152.630435  ...  116.239130
# 17     156.540107  158.564171  160.430481  162.077540  ...  123.211230
# 18     167.620000  169.354286  171.022857  172.257143  ...  128.557143
# 19     175.767705  176.450425  176.960340  177.430595  ...  181.886686
# 20     153.693939  156.151515  158.460606  160.224242  ...  133.409091
# 21     165.033333  167.203030  168.433333  169.866667  ...  138.863636
# 22     146.858434  151.424699  154.006024  156.963855  ...  127.207831
# 23     162.719764  165.026549  167.091445  168.725664  ...  156.575221
# 24     165.205882  167.192810  168.983660  170.271242  ...  153.370492
#
#          pixel776    pixel777    pixel778    pixel779    pixel780    pixel781  \
# label
# 0      165.008876  179.467456  189.286982  189.908284  186.136095  183.875740
# 1      141.768456  148.828859  146.751678  146.610738  147.788591  147.637584
# 2      205.405325  204.896450  205.491124  204.964497  204.281065  203.979290
# 3      117.655462  134.607843  143.140056  143.652661  144.820728  145.540616
# 4      136.555556  152.921147  166.534050  178.731183  181.982079  180.817204
# 5      165.614243  168.531157  170.323442  171.077151  169.623145  169.296736
# 6      141.741641  143.158055  141.483283  139.857143  141.224924  140.942249
# 7      157.154882  154.161616  158.239057  157.447811  156.168350  155.643098
# 8      166.017442  174.462209  176.537791  173.584302  174.976744  176.610465
# 10     126.605178  131.812298  145.051780  160.255663  163.909385  162.000000
# 11     169.820728  169.184874  166.456583  167.854342  165.781513  166.056022
# 12     141.717770  152.554007  166.432056  170.261324  173.383275  177.540070
# 13     140.841317  155.443114  161.517964  161.356287  162.913174  161.338323
# 14     180.879213  183.581461  185.758427  184.873596  183.494382  181.693820
# 15     101.145695   99.745033   96.132450   94.314570   94.364238   92.589404
# 16     119.597826  125.062500  131.676630  133.578804  131.146739  137.600543
# 17     134.770053  144.029412  153.312834  163.890374  166.144385  165.243316
# 18     138.768571  145.771429  157.700000  163.597143  166.482857  170.308571
# 19     179.532578  176.957507  178.490085  179.328612  177.014164  173.711048
# 20     139.066667  152.627273  168.606061  172.506061  178.006061  181.142424
# 21     149.221212  149.557576  157.848485  169.163636  168.472727  161.990909
# 22     131.234940  135.403614  143.334337  153.195783  159.069277  162.292169
# 23     161.908555  164.286136  164.197640  163.587021  163.952802  163.802360
# 24     154.252459  159.177049  163.655738  164.773770  167.101639  169.400000
#
#          pixel782    pixel783    pixel784
# label
# 0      182.949704  178.943787  174.633136
# 1      146.322148  142.046980  136.298658
# 2      203.505917  202.881657  199.316568
# 3      144.672269  144.801120  139.117647
# 4      178.297491  178.706093  181.505376
# 5      168.910979  166.454006  166.278932
# 6      136.112462  135.446809  134.200608
# 7      146.434343  140.528620  143.518519
# 8      173.581395  167.610465  164.276163
# 10     161.080906  161.449838  159.828479
# 11     163.969188  165.607843  166.918768
# 12     173.268293  176.108014  174.564460
# 13     163.601796  164.419162  161.236527
# 14     179.873596  175.660112  171.202247
# 15     101.632450  110.907285  120.791391
# 16     146.342391  148.154891  146.464674
# 17     164.034759  161.877005  161.951872
# 18     170.751429  169.574286  170.542857
# 19     171.379603  171.201133  168.912181
# 20     177.360606  174.833333  174.772727
# 21     158.018182  155.124242  152.081818
# 22     159.722892  158.707831  154.448795
# 23     165.946903  169.368732  171.766962
# 24     165.901639  161.150820  162.288525
#
# [24 rows x 784 columns]

# %%
#creating a duplicate dataframe and filling missing values
train_df_filled = train_data.copy()
train_df_filled.iloc[:,1:] = train_data.groupby('label').transform(lambda x: x.fillna(x.mean()))

# %%
train_df_filled.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Count the number of samples for each label
plt.figure(figsize=(12,6))
sns.countplot(x=train_df_filled['label'], palette='viridis')

plt.title("Class Distribution of ASL data in Training Dataset")
plt.xlabel("ASL Alphabet(label)")
plt.ylabel("Number of images")
plt.xticks(rotation=0)

plt.show()
# Out:
# <ipython-input-21-3f66bd4f67c3>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=train_df_filled['label'], palette='viridis')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Extract Label and pixel values
labels = train_df_filled['label'].values
images = train_df_filled.iloc[:,1:].values

#Reshape few images to 28x28
images = images.reshape(-1, 28, 28)

#Plot some sample images
fig, axes = plt.subplots(5,5, figsize=(12,6))
axes = axes.ravel()


for i in range(25):
  axes[i].imshow(images[i], cmap='gray')
  axes[i].set_title(f"label: {labels[i]}")
  axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
#Plotting Pixel Intensity Histogram
import numpy as np
import matplotlib.pyplot as plt

#Flatten all pixel values into a single array
pixel_data = train_df_filled.iloc[:, 1:].values.flatten()

#Plot histogram of Pixel intensity
plt.figure(figsize=(10,5))
plt.hist(pixel_data, bins=50, color='skyblue', alpha=0.7, edgecolor='black')
plt.title('Pixel Intensity Distribution')
plt.xlabel("Pixel Intensity (0-255)")
plt.ylabel("Frequencey")
plt.show()

# %%
#Plotting heatmap of pixel correlation
import seaborn as sns

#Computing correlation matrix for small number of pixel
corr_matrix = train_df_filled.iloc[:,1:50].corr()

#Plot the heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, linewidths=0.5)
plt.title("Pixel Correlation Heatmap")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Randomly selecting 5 images from the dataset
random_indices = np.random.choice(len(images), 5,  replace = False)
sample_images = images[random_indices]

#Plot the original and edge-detected image
fig, axes = plt.subplots(5,4, figsize=(15,15))

for i, img in enumerate(sample_images):
  sobelx = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize=5)
  sobely = cv2.Sobel(img, cv2.CV_64F, 0,1, ksize=5)

  canny_edges= cv2.Canny(np.uint8(img), 50, 150)

  axes[i,0].imshow(img, cmap='gray')
  axes[i,0].set_title("Original Image")
  axes[i,1].imshow(sobelx, cmap='gray')
  axes[i,1].set_title("Sobel X")
  axes[i,2].imshow(sobely, cmap='gray')
  axes[i,2].set_title("Sobel Y")
  axes[i,3].imshow(canny_edges, cmap='gray')
  axes[i,3].set_title("Canny Edges")

  for ax in axes[i]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
#Statistical summary
pixel_stats= train_df_filled.iloc[:,1:].describe().T

pixel_stats.head()
# Out:
#          count        mean        std  min     25%    50%    75%    max
# pixel1  7944.0  146.254406  41.591206  0.0  122.00  151.0  175.0  255.0
# pixel2  7944.0  149.332704  40.130854  0.0  126.00  154.0  177.0  255.0
# pixel3  7944.0  152.140987  39.115021  0.0  131.00  156.0  179.0  255.0
# pixel4  7944.0  154.387966  38.612513  0.0  134.00  159.0  180.0  255.0
# pixel5  7944.0  156.900554  37.328899  0.0  137.75  160.0  181.0  255.0

# %%
#Normalizing the data
train_df_normalized = train_df_filled.copy()
train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:]/255.0

print("After Normalization : ")
print("Min Pixel value : ", train_df_normalized.iloc[:,1:].min().min())
print("Max Pixel value : ", train_df_normalized.iloc[:,1:].max().max())
# Out:
# Streaming output truncated to the last 5000 lines.
#         ...
# 7939     96.0
# 7940    170.0
# 7941    253.0
# 7942    194.0
# 7943    198.0
# Name: pixel344, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       175.0
# 1       151.0
# 2       118.0
# 3       225.0
# 4       203.0
#         ...
# 7939     93.0
# 7940    141.0
# 7941    210.0
# 7942    191.0
# 7943    160.0
# Name: pixel345, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       182.0
# 1       148.0
# 2        87.0
# 3       205.0
# 4       172.0
#         ...
# 7939     91.0
# 7940    167.0
# 7941    184.0
# 7942    194.0
# 7943    121.0
# Name: pixel346, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       179.0
# 1       151.0
# 2        80.0
# 3       167.0
# 4       136.0
#         ...
# 7939    101.0
# 7940    155.0
# 7941    156.0
# 7942    194.0
# 7943    161.0
# Name: pixel347, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       171.0
# 1       154.0
# 2        78.0
# 3       102.0
# 4       150.0
#         ...
# 7939    105.0
# 7940     91.0
# 7941    145.0
# 7942    195.0
# 7943    156.0
# Name: pixel348, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       159.0
# 1       153.0
# 2        75.0
# 3        82.0
# 4       127.0
#         ...
# 7939    106.0
# 7940     43.0
# 7941    163.0
# 7942    193.0
# 7943    134.0
# Name: pixel349, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       114.0
# 1       153.0
# 2       110.0
# 3        81.0
# 4        89.0
#         ...
# 7939    112.0
# 7940     29.0
# 7941    228.0
# 7942    195.0
# 7943    183.0
# Name: pixel350, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       102.0
# 1       148.0
# 2       202.0
# 3        73.0
# 4        76.0
#         ...
# 7939    112.0
# 7940     13.0
# 7941    255.0
# 7942    193.0
# 7943    138.0
# Name: pixel351, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        89.0
# 1       153.0
# 2       197.0
# 3        62.0
# 4       131.0
#         ...
# 7939    105.0
# 7940    140.0
# 7941    226.0
# 7942    190.0
# 7943     94.0
# Name: pixel352, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       121.0
# 1       147.0
# 2       197.0
# 3       143.0
# 4       118.0
#         ...
# 7939     75.0
# 7940    170.0
# 7941    180.0
# 7942    184.0
# 7943    152.0
# Name: pixel353, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       136.0
# 1       140.0
# 2       196.0
# 3       221.0
# 4       118.0
#         ...
# 7939     41.0
# 7940    161.0
# 7941    122.0
# 7942    115.0
# 7943    199.0
# Name: pixel354, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       136.0
# 1       171.0
# 2       195.0
# 3       215.0
# 4       188.0
#         ...
# 7939    105.0
# 7940    163.0
# 7941     87.0
# 7942     75.0
# 7943    190.0
# Name: pixel355, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        96.0
# 1       176.0
# 2       194.0
# 3       216.0
# 4       177.0
#         ...
# 7939    164.0
# 7940    162.0
# 7941    119.0
# 7942    152.0
# 7943    191.0
# Name: pixel356, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       172.0
# 1       173.0
# 2       194.0
# 3       215.0
# 4       153.0
#         ...
# 7939    151.0
# 7940    161.0
# 7941    126.0
# 7942    190.0
# 7943    189.0
# Name: pixel357, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       173.0
# 2       193.0
# 3       211.0
# 4       133.0
#         ...
# 7939    149.0
# 7940    158.0
# 7941    127.0
# 7942    187.0
# 7943    187.0
# Name: pixel358, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       171.0
# 2       192.0
# 3       211.0
# 4       113.0
#         ...
# 7939    149.0
# 7940    156.0
# 7941    172.0
# 7942    186.0
# 7943    181.0
# Name: pixel359, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       185.0
# 1       170.0
# 2       191.0
# 3       210.0
# 4        88.0
#         ...
# 7939    148.0
# 7940    155.0
# 7941    224.0
# 7942    186.0
# 7943    166.0
# Name: pixel360, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       185.0
# 1       168.0
# 2       190.0
# 3       185.0
# 4       168.0
#         ...
# 7939    144.0
# 7940    153.0
# 7941    215.0
# 7942    186.0
# 7943    148.0
# Name: pixel361, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       184.0
# 1       167.0
# 2       185.0
# 3       166.0
# 4       212.0
#         ...
# 7939    139.0
# 7940    150.0
# 7941    215.0
# 7942    186.0
# 7943    152.0
# Name: pixel362, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       182.0
# 1       165.0
# 2       169.0
# 3       108.0
# 4       210.0
#         ...
# 7939    138.0
# 7940    149.0
# 7941    215.0
# 7942    184.0
# 7943    184.0
# Name: pixel363, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       181.0
# 1       163.0
# 2       161.0
# 3       168.0
# 4       210.0
#         ...
# 7939    137.0
# 7940    148.0
# 7941    214.0
# 7942    183.0
# 7943    182.0
# Name: pixel364, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       131.0
# 1       182.0
# 2       202.0
# 3       231.0
# 4       180.0
#         ...
# 7939    153.0
# 7940    177.0
# 7941    179.0
# 7942    190.0
# 7943    185.0
# Name: pixel365, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       140.0
# 1       181.0
# 2       202.0
# 3       232.0
# 4       182.0
#         ...
# 7939    154.0
# 7940    177.0
# 7941    184.0
# 7942    192.0
# 7943    188.0
# Name: pixel366, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       147.0
# 1       181.0
# 2       203.0
# 3       232.0
# 4       185.0
#         ...
# 7939    155.0
# 7940    177.0
# 7941    190.0
# 7942    194.0
# 7943    188.0
# Name: pixel367, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       154.0
# 1       182.0
# 2       202.0
# 3       234.0
# 4       189.0
#         ...
# 7939    156.0
# 7940    176.0
# 7941    196.0
# 7942    196.0
# 7943    202.0
# Name: pixel368, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       157.0
# 1       179.0
# 2       207.0
# 3       227.0
# 4       192.0
#         ...
# 7939    156.0
# 7940    176.0
# 7941    198.0
# 7942    194.0
# 7943    207.0
# Name: pixel369, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       160.0
# 1       164.0
# 2       237.0
# 3       225.0
# 4       195.0
#         ...
# 7939    128.0
# 7940    176.0
# 7941    204.0
# 7942    202.0
# 7943    202.0
# Name: pixel370, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       164.0
# 1       149.0
# 2       210.0
# 3       248.0
# 4       197.0
#         ...
# 7939    118.0
# 7940    178.0
# 7941    248.0
# 7942    203.0
# 7943    210.0
# Name: pixel371, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       179.0
# 1       156.0
# 2       158.0
# 3       241.0
# 4       213.0
#         ...
# 7939    119.0
# 7940    158.0
# 7941    214.0
# 7942    192.0
# 7943    204.0
# Name: pixel372, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       159.0
# 2       108.0
# 3       213.0
# 4       202.0
#         ...
# 7939     99.0
# 7940    154.0
# 7941    206.0
# 7942    194.0
# 7943    171.0
# Name: pixel373, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       191.0
# 1       153.0
# 2        81.0
# 3       201.0
# 4       173.0
#         ...
# 7939     98.0
# 7940    174.0
# 7941    180.0
# 7942    188.0
# 7943    105.0
# Name: pixel374, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       187.0
# 1       153.0
# 2        76.0
# 3       164.0
# 4       142.0
#         ...
# 7939     98.0
# 7940    143.0
# 7941    153.0
# 7942    178.0
# 7943    126.0
# Name: pixel375, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       180.0
# 1       166.0
# 2        76.0
# 3       108.0
# 4       135.0
#         ...
# 7939    106.0
# 7940     86.0
# 7941    138.0
# 7942    193.0
# 7943    170.0
# Name: pixel376, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       157.0
# 1       173.0
# 2        75.0
# 3        68.0
# 4       128.0
#         ...
# 7939    115.0
# 7940     51.0
# 7941    161.0
# 7942    198.0
# 7943    102.0
# Name: pixel377, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       100.0
# 1       169.0
# 2       116.0
# 3        73.0
# 4       109.0
#         ...
# 7939    111.0
# 7940     21.0
# 7941    193.0
# 7942    192.0
# 7943    142.0
# Name: pixel378, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        88.0
# 1       169.0
# 2       205.0
# 3        72.0
# 4        76.0
#         ...
# 7939    105.0
# 7940     50.0
# 7941    255.0
# 7942    186.0
# 7943    135.0
# Name: pixel379, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        84.0
# 1       163.0
# 2       197.0
# 3       177.0
# 4       151.0
#         ...
# 7939    100.0
# 7940    175.0
# 7941    239.0
# 7942    182.0
# 7943     98.0
# Name: pixel380, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       108.0
# 1       151.0
# 2       198.0
# 3       229.0
# 4       146.0
#         ...
# 7939     66.0
# 7940    165.0
# 7941    201.0
# 7942    162.0
# 7943    109.0
# Name: pixel381, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       111.0
# 1       105.0
# 2       198.0
# 3       219.0
# 4       168.0
#         ...
# 7939     22.0
# 7940    165.0
# 7941    159.0
# 7942    106.0
# 7943    200.0
# Name: pixel382, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       126.0
# 1       141.0
# 2       196.0
# 3       218.0
# 4       194.0
#         ...
# 7939    117.0
# 7940    165.0
# 7941    113.0
# 7942     70.0
# 7943    192.0
# Name: pixel383, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        90.0
# 1       182.0
# 2       195.0
# 3       219.0
# 4       179.0
#         ...
# 7939    152.0
# 7940    164.0
# 7941    119.0
# 7942    123.0
# 7943    191.0
# Name: pixel384, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       120.0
# 1       174.0
# 2       195.0
# 3       218.0
# 4       152.0
#         ...
# 7939    144.0
# 7940    162.0
# 7941    131.0
# 7942    191.0
# 7943    190.0
# Name: pixel385, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       175.0
# 2       194.0
# 3       216.0
# 4       119.0
#         ...
# 7939    145.0
# 7940    161.0
# 7941    135.0
# 7942    187.0
# 7943    178.0
# Name: pixel386, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       187.0
# 1       173.0
# 2       193.0
# 3       215.0
# 4        98.0
#         ...
# 7939    144.0
# 7940    158.0
# 7941    184.0
# 7942    187.0
# 7943    144.0
# Name: pixel387, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       187.0
# 1       171.0
# 2       191.0
# 3       214.0
# 4        84.0
#         ...
# 7939    143.0
# 7940    157.0
# 7941    225.0
# 7942    187.0
# 7943    109.0
# Name: pixel388, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       171.0
# 2       189.0
# 3       198.0
# 4       171.0
#         ...
# 7939    141.0
# 7940    153.0
# 7941    216.0
# 7942    186.0
# 7943     91.0
# Name: pixel389, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       185.0
# 1       168.0
# 2       186.0
# 3       181.0
# 4       212.0
#         ...
# 7939    141.0
# 7940    152.0
# 7941    217.0
# 7942    186.0
# 7943     89.0
# Name: pixel390, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       184.0
# 1       166.0
# 2       174.0
# 3       156.0
# 4       210.0
#         ...
# 7939    139.0
# 7940    151.0
# 7941    215.0
# 7942    185.0
# 7943    168.0
# Name: pixel391, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       182.0
# 1       165.0
# 2       182.0
# 3       152.0
# 4       211.0
#         ...
# 7939    137.0
# 7940    149.0
# 7941    214.0
# 7942    185.0
# 7943    187.0
# Name: pixel392, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       133.0
# 1       183.0
# 2       202.0
# 3       233.0
# 4       181.0
#         ...
# 7939    154.0
# 7940    179.0
# 7941    178.0
# 7942    190.0
# 7943    188.0
# Name: pixel393, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       141.0
# 1       183.0
# 2       203.0
# 3       233.0
# 4       182.0
#         ...
# 7939    155.0
# 7940    178.0
# 7941    184.0
# 7942    192.0
# 7943    189.0
# Name: pixel394, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       149.0
# 1       183.0
# 2       205.0
# 3       235.0
# 4       186.0
#         ...
# 7939    157.0
# 7940    178.0
# 7941    192.0
# 7942    195.0
# 7943    190.0
# Name: pixel395, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       155.0
# 1       182.0
# 2       200.0
# 3       230.0
# 4       189.0
#         ...
# 7939    157.0
# 7940    179.0
# 7941    198.0
# 7942    197.0
# 7943    198.0
# Name: pixel396, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       158.0
# 1       171.0
# 2       218.0
# 3       226.0
# 4       193.0
#         ...
# 7939    148.0
# 7940    179.0
# 7941    196.0
# 7942    196.0
# 7943    205.0
# Name: pixel397, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       160.0
# 1       159.0
# 2       238.0
# 3       246.0
# 4       196.0
#         ...
# 7939    143.0
# 7940    179.0
# 7941    221.0
# 7942    201.0
# 7943    209.0
# Name: pixel398, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       174.0
# 1       130.0
# 2       202.0
# 3       243.0
# 4       199.0
#         ...
# 7939    150.0
# 7940    178.0
# 7941    252.0
# 7942    203.0
# 7943    206.0
# Name: pixel399, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       201.0
# 1       125.0
# 2       151.0
# 3       224.0
# 4       213.0
#         ...
# 7939    120.0
# 7940    150.0
# 7941    202.0
# 7942    203.0
# 7943    188.0
# Name: pixel400, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       189.0
# 1       135.0
# 2       105.0
# 3       208.0
# 4       202.0
#         ...
# 7939     99.0
# 7940    167.0
# 7941    194.0
# 7942    202.0
# 7943    146.0
# Name: pixel401, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       165.0
# 1       134.0
# 2        82.0
# 3       181.0
# 4       180.0
#         ...
# 7939     91.0
# 7940    166.0
# 7941    203.0
# 7942    200.0
# 7943    102.0
# Name: pixel402, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       151.0
# 1       130.0
# 2        79.0
# 3       132.0
# 4       159.0
#         ...
# 7939    100.0
# 7940    132.0
# 7941    173.0
# 7942    202.0
# 7943     97.0
# Name: pixel403, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       143.0
# 1       137.0
# 2        80.0
# 3       101.0
# 4       133.0
#         ...
# 7939    114.0
# 7940     85.0
# 7941    129.0
# 7942    206.0
# 7943    131.0
# Name: pixel404, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       146.0
# 1       146.0
# 2        75.0
# 3        82.0
# 4       116.0
#         ...
# 7939    111.0
# 7940     44.0
# 7941    181.0
# 7942    197.0
# 7943     85.0
# Name: pixel405, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       120.0
# 1       147.0
# 2       129.0
# 3        58.0
# 4       111.0
#         ...
# 7939    105.0
# 7940     12.0
# 7941    240.0
# 7942    187.0
# 7943    110.0
# Name: pixel406, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        87.0
# 1       164.0
# 2       206.0
# 3       131.0
# 4        70.0
#         ...
# 7939     98.0
# 7940     70.0
# 7941    255.0
# 7942    180.0
# 7943    156.0
# Name: pixel407, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        78.0
# 1       165.0
# 2       198.0
# 3       237.0
# 4       149.0
#         ...
# 7939     86.0
# 7940    180.0
# 7941    246.0
# 7942    172.0
# 7943    104.0
# Name: pixel408, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        87.0
# 1       147.0
# 2       199.0
# 3       219.0
# 4       183.0
#         ...
# 7939     51.0
# 7940    166.0
# 7941    218.0
# 7942    147.0
# 7943     97.0
# Name: pixel409, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        76.0
# 1       103.0
# 2       198.0
# 3       222.0
# 4       204.0
#         ...
# 7939     19.0
# 7940    167.0
# 7941    182.0
# 7942     98.0
# 7943    201.0
# Name: pixel410, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       108.0
# 1       151.0
# 2       197.0
# 3       222.0
# 4       193.0
#         ...
# 7939    132.0
# 7940    167.0
# 7941    137.0
# 7942     67.0
# 7943    193.0
# Name: pixel411, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        98.0
# 1       182.0
# 2       196.0
# 3       220.0
# 4       170.0
#         ...
# 7939    154.0
# 7940    165.0
# 7941    129.0
# 7942    104.0
# 7943    190.0
# Name: pixel412, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        96.0
# 1       176.0
# 2       196.0
# 3       217.0
# 4       143.0
#         ...
# 7939    147.0
# 7940    163.0
# 7941    142.0
# 7942    190.0
# 7943    183.0
# Name: pixel413, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       181.0
# 1       176.0
# 2       194.0
# 3       216.0
# 4       110.0
#         ...
# 7939    147.0
# 7940    161.0
# 7941    136.0
# 7942    189.0
# 7943    144.0
# Name: pixel414, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       188.0
# 1       175.0
# 2       193.0
# 3       216.0
# 4        89.0
#         ...
# 7939    147.0
# 7940    160.0
# 7941    196.0
# 7942    188.0
# 7943    102.0
# Name: pixel415, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       187.0
# 1       173.0
# 2       192.0
# 3       215.0
# 4        93.0
#         ...
# 7939    146.0
# 7940    160.0
# 7941    225.0
# 7942    188.0
# 7943     72.0
# Name: pixel416, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       172.0
# 2       190.0
# 3       208.0
# 4       192.0
#         ...
# 7939    145.0
# 7940    159.0
# 7941    218.0
# 7942    187.0
# 7943    102.0
# Name: pixel417, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       186.0
# 1       170.0
# 2       189.0
# 3       182.0
# 4       213.0
#         ...
# 7939    142.0
# 7940    154.0
# 7941    218.0
# 7942    186.0
# 7943    136.0
# Name: pixel418, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       185.0
# 1       167.0
# 2       184.0
# 3       184.0
# 4       211.0
#         ...
# 7939    140.0
# 7940    153.0
# 7941    217.0
# 7942    185.0
# 7943    179.0
# Name: pixel419, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       183.0
# 1       166.0
# 2       166.0
# 3       167.0
# 4       211.0
#         ...
# 7939    139.0
# 7940    152.0
# 7941    215.0
# 7942    186.0
# 7943    184.0
# Name: pixel420, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       133.0
# 1       184.0
# 2       204.0
# 3       235.0
# 4       181.0
#         ...
# 7939    154.0
# 7940    180.0
# 7941    179.0
# 7942    192.0
# 7943    189.0
# Name: pixel421, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       141.0
# 1       185.0
# 2       204.0
# 3       236.0
# 4       184.0
#         ...
# 7939    155.0
# 7940    180.0
# 7941    186.0
# 7942    193.0
# 7943    190.0
# Name: pixel422, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       150.0
# 1       185.0
# 2       207.0
# 3       234.0
# 4       187.0
#         ...
# 7939    157.0
# 7940    180.0
# 7941    192.0
# 7942    195.0
# 7943    191.0
# Name: pixel423, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       156.0
# 1       176.0
# 2       202.0
# 3       226.0
# 4       190.0
#         ...
# 7939    159.0
# 7940    180.0
# 7941    198.0
# 7942    197.0
# 7943    210.0
# Name: pixel424, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       160.0
# 1       174.0
# 2       234.0
# 3       250.0
# 4       194.0
#         ...
# 7939    150.0
# 7940    179.0
# 7941    193.0
# 7942    197.0
# 7943    212.0
# Name: pixel425, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       161.0
# 1       163.0
# 2       228.0
# 3       250.0
# 4       196.0
#         ...
# 7939    149.0
# 7940    183.0
# 7941    230.0
# 7942    198.0
# 7943    197.0
# Name: pixel426, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       179.0
# 1       147.0
# 2       186.0
# 3       230.0
# 4       200.0
#         ...
# 7939    150.0
# 7940    168.0
# 7941    255.0
# 7942    214.0
# 7943    189.0
# Name: pixel427, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       197.0
# 1       145.0
# 2       141.0
# 3       218.0
# 4       214.0
#         ...
# 7939    126.0
# 7940    147.0
# 7941    229.0
# 7942    217.0
# 7943    178.0
# Name: pixel428, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       174.0
# 1       142.0
# 2        97.0
# 3       201.0
# 4       203.0
#         ...
# 7939    113.0
# 7940    175.0
# 7941    197.0
# 7942    204.0
# 7943    138.0
# Name: pixel429, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       135.0
# 1       141.0
# 2        80.0
# 3       162.0
# 4       183.0
#         ...
# 7939    113.0
# 7940    168.0
# 7941    189.0
# 7942    202.0
# 7943    103.0
# Name: pixel430, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        99.0
# 1       141.0
# 2        80.0
# 3       124.0
# 4       166.0
#         ...
# 7939    119.0
# 7940    118.0
# 7941    177.0
# 7942    203.0
# 7943     63.0
# Name: pixel431, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        72.0
# 1       133.0
# 2        79.0
# 3        93.0
# 4       149.0
#         ...
# 7939    111.0
# 7940     72.0
# 7941    167.0
# 7942    194.0
# 7943     98.0
# Name: pixel432, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        95.0
# 1       125.0
# 2        68.0
# 3        62.0
# 4       119.0
#         ...
# 7939    107.0
# 7940     34.0
# 7941    228.0
# 7942    181.0
# 7943    101.0
# Name: pixel433, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       134.0
# 1       125.0
# 2       136.0
# 3        82.0
# 4       104.0
#         ...
# 7939    100.0
# 7940     10.0
# 7941    255.0
# 7942    176.0
# 7943    141.0
# Name: pixel434, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        97.0
# 1       135.0
# 2       209.0
# 3       214.0
# 4       109.0
#         ...
# 7939     84.0
# 7940    113.0
# 7941    249.0
# 7942    182.0
# 7943    175.0
# ...
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       200.0
# 1       102.0
# 2       192.0
# 3       219.0
# 4       216.0
#         ...
# 7939    146.0
# 7940    167.0
# 7941    129.0
# 7942    197.0
# 7943    195.0
# Name: pixel699, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       200.0
# 1       100.0
# 2       191.0
# 3       217.0
# 4       217.0
#         ...
# 7939    145.0
# 7940    165.0
# 7941    130.0
# 7942    196.0
# 7943    194.0
# Name: pixel700, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       142.0
# 1       162.0
# 2       212.0
# 3        65.0
# 4       130.0
#         ...
# 7939    160.0
# 7940    192.0
# 7941    144.0
# 7942    200.0
# 7943    123.0
# Name: pixel701, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       150.0
# 1       159.0
# 2       198.0
# 3        62.0
# 4       134.0
#         ...
# 7939    160.0
# 7940    182.0
# 7941    145.0
# 7942    202.0
# 7943     95.0
# Name: pixel702, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       159.0
# 1       145.0
# 2       175.0
# 3        58.0
# 4       139.0
#         ...
# 7939    161.0
# 7940    164.0
# 7941    144.0
# 7942    204.0
# 7943     94.0
# Name: pixel703, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       165.0
# 1       112.0
# 2       158.0
# 3        55.0
# 4       143.0
#         ...
# 7939    164.0
# 7940    157.0
# 7941    147.0
# 7942    206.0
# 7943     90.0
# Name: pixel704, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       170.0
# 1        85.0
# 2       136.0
# 3        63.0
# 4       147.0
#         ...
# 7939    148.0
# 7940    152.0
# 7941    131.0
# 7942    208.0
# 7943    160.0
# Name: pixel705, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       191.0
# 1        75.0
# 2       103.0
# 3        44.0
# 4       146.0
#         ...
# 7939    123.0
# 7940    157.0
# 7941    205.0
# 7942    208.0
# 7943    204.0
# Name: pixel706, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       173.0
# 1        68.0
# 2        85.0
# 3        11.0
# 4       173.0
#         ...
# 7939    126.0
# 7940    131.0
# 7941    255.0
# 7942    195.0
# 7943    190.0
# Name: pixel707, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       157.0
# 1        65.0
# 2        76.0
# 3        22.0
# 4       200.0
#         ...
# 7939    124.0
# 7940     93.0
# 7941    247.0
# 7942    187.0
# 7943    156.0
# Name: pixel708, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       144.0
# 1        64.0
# 2        81.0
# 3        24.0
# 4       187.0
#         ...
# 7939    116.0
# 7940     64.0
# 7941    236.0
# 7942    183.0
# 7943    160.0
# Name: pixel709, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       119.0
# 1        62.0
# 2        89.0
# 3        28.0
# 4       178.0
#         ...
# 7939     98.0
# 7940     50.0
# 7941    213.0
# 7942    177.0
# 7943    163.0
# Name: pixel710, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        97.0
# 1        79.0
# 2        92.0
# 3        34.0
# 4       174.0
#         ...
# 7939     73.0
# 7940     31.0
# 7941    210.0
# 7942    164.0
# 7943    129.0
# Name: pixel711, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        84.0
# 1       123.0
# 2        88.0
# 3        49.0
# 4       150.0
#         ...
# 7939     53.0
# 7940     29.0
# 7941    241.0
# 7942    149.0
# 7943    102.0
# Name: pixel712, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        79.0
# 1       192.0
# 2        69.0
# 3        46.0
# 4       143.0
#         ...
# 7939     40.0
# 7940     22.0
# 7941    235.0
# 7942    120.0
# 7943     75.0
# Name: pixel713, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        79.0
# 1       198.0
# 2       108.0
# 3        62.0
# 4       149.0
#         ...
# 7939     21.0
# 7940     16.0
# 7941    202.0
# 7942     95.0
# 7943    174.0
# Name: pixel714, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        91.0
# 1       183.0
# 2       195.0
# 3        95.0
# 4       138.0
#         ...
# 7939     45.0
# 7940     37.0
# 7941    183.0
# 7942     84.0
# 7943    216.0
# Name: pixel715, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       172.0
# 1       126.0
# 2       208.0
# 3       109.0
# 4       108.0
#         ...
# 7939    161.0
# 7940    135.0
# 7941    179.0
# 7942     75.0
# 7943    205.0
# Name: pixel716, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       202.0
# 1        81.0
# 2       204.0
# 3       141.0
# 4        94.0
#         ...
# 7939    160.0
# 7940    193.0
# 7941    162.0
# 7942     92.0
# 7943    206.0
# Name: pixel717, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       203.0
# 1       123.0
# 2       203.0
# 3       202.0
# 4        81.0
#         ...
# 7939    159.0
# 7940    180.0
# 7941    142.0
# 7942    195.0
# 7943    206.0
# Name: pixel718, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       203.0
# 1       137.0
# 2       203.0
# 3       237.0
# 4        94.0
#         ...
# 7939    158.0
# 7940    180.0
# 7941    140.0
# 7942    204.0
# 7943    206.0
# Name: pixel719, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       205.0
# 1       129.0
# 2       201.0
# 3       240.0
# 4       178.0
#         ...
# 7939    156.0
# 7940    179.0
# 7941    141.0
# 7942    203.0
# 7943    204.0
# Name: pixel720, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       204.0
# 1       154.0
# 2       200.0
# 3       231.0
# 4       198.0
#         ...
# 7939    154.0
# 7940    177.0
# 7941    138.0
# 7942    202.0
# 7943    204.0
# Name: pixel721, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       204.0
# 1       217.0
# 2       200.0
# 3       226.0
# 4       201.0
#         ...
# 7939    153.0
# 7940    177.0
# 7941    137.0
# 7942    201.0
# 7943    203.0
# Name: pixel722, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       204.0
# 1       133.0
# 2       199.0
# 3       226.0
# 4       204.0
#         ...
# 7939    152.0
# 7940    175.0
# 7941    136.0
# 7942    201.0
# 7943    201.0
# Name: pixel723, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       203.0
# 1        87.0
# 2       196.0
# 3       224.0
# 4       206.0
#         ...
# 7939    150.0
# 7940    173.0
# 7941    135.0
# 7942    201.0
# 7943    201.0
# Name: pixel724, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       202.0
# 1        87.0
# 2       195.0
# 3       222.0
# 4       208.0
#         ...
# 7939    149.0
# 7940    171.0
# 7941    135.0
# 7942    200.0
# 7943    200.0
# Name: pixel725, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       202.0
# 1        91.0
# 2       195.0
# 3       220.0
# 4       209.0
#         ...
# 7939    148.0
# 7940    170.0
# 7941    135.0
# 7942    198.0
# 7943    197.0
# Name: pixel726, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       201.0
# 1       101.0
# 2       193.0
# 3       219.0
# 4       211.0
#         ...
# 7939    147.0
# 7940    169.0
# 7941    133.0
# 7942    196.0
# 7943    196.0
# Name: pixel727, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-39-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       200.0
# 1        94.0
# 2       192.0
# 3       217.0
# 4       211.0
#         ...
# 7939    145.0
# 7940    167.0
# 7941    134.0
# 7942    194.0
# 7943    195.0
# Name: pixel728, Length: 7944, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# After Normalization :
# Min Pixel value :  0.0
# Max Pixel value :  1.0
