# %% [markdown]
# # **Sign Language Recognition using Deep Learning: MNIST Dataset Analysis**
# ![Sign_Language_Image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Abstract**:
# Sign language is a crucial means of communication for individuals with hearing impairments. In this project:
#
#
# * We aim to develop a fully functional AI system using deep learning techniques,
# specifically neural networks, to recognize hand gestures corresponding to American Sign Language (ASL) alphabets.
# * Using the Sign Language MNIST dataset, we will conduct Exploratory Data Analysis (EDA), preprocess the data, and train a classification model to accurately identify different hand signs.
# * This project aims to enhance accessibility and communication by leveraging state-of-the-art deep learning models for sign language recognition.

# %% [markdown]
# # **Problem Statement:**
# People with hearing impairments primarily rely on sign language for communication. However, many individuals are unfamiliar with sign language, creating a barrier between the deaf and hearing communities. Traditional text-based communication methods are often ineffective in real-time conversations.
#
# The Sign Language MNIST dataset provides an opportunity to train a deep learning model using neural networks to recognize ASL alphabets from hand gesture images. This project aims to develop an AI-powered system that accurately interprets sign language symbols and translates them into readable text. By leveraging Convolutional Neural Networks (CNNs) and other deep learning techniques, we aim to create a robust model that enhances accessibility and inclusivity for individuals with hearing impairments.

# %% [markdown]
# ## **Objectives**:
#
#
# 1.   Develop a Sign Language Recognition System – Train a deep learning model using neural networks to classify hand signs representing ASL alphabets.
#
# 1.   Perform Exploratory Data Analysis (EDA) – Analyze the dataset to understand its structure, distribution, and potential challenges before training the model.
#
# 1.   Preprocess and Augment Data – Apply necessary transformations, such as normalization, resizing, and augmentation, to enhance model performance and generalization.
# 2.   Train and Evaluate Deep Learning Models – Experiment with different neural network architectures (e.g., Convolutional Neural Networks - CNNs) to achieve high accuracy.
#
# 1.   Optimize and Fine-Tune the Model – Use techniques such as hyperparameter tuning, dropout, and batch normalization to improve the model's efficiency and robustness.

# %% [markdown]
# # **Name and Source of Dataset**
# Dataset Name: Sign Language MNIST
#
# Source: https://www.kaggle.com/datasets/datamunge/sign-language-mnist/data/
#
# Description: The dataset contains images of hand signs corresponding to the
# American Sign Language (ASL) alphabets, specifically A to Y (excluding J and Z, as they require motion).

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**
#
#       We'll analyze the dataset to understand:
#         1.   Understanding the dataset and its shape
#         2.   Checking the type of data and each column
#         3.   Categorical and Numerical Columns
#         4.   Checking for missing values and inconsistencies
#         5.   Descriptive summary of the dataset
#         6.   Groupby for classification problem
#         7.   The distribution of images across classes
#         8.   Sample images for visualization

# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
#loading the training dataset from csv file to pandas data frame
train_data = pd.read_csv('/content/sign_mnist_train.csv')

# %%
#printing the first five rows of the dataframe
train_data.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
train_data.shape
# Out:
# (27455, 785)

# %%
#checking the datatypes
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
train_data.isnull().sum()
# Out:
# label       0
# pixel1      0
# pixel2      0
# pixel3      0
# pixel4      0
#            ..
# pixel780    0
# pixel781    0
# pixel782    0
# pixel783    0
# pixel784    0
# Length: 785, dtype: int64

# %%
missing_values=train_data.isnull().sum().sum()
print("Total Missing Values in Dataset:", missing_values)
# Out:
# Total Missing Values in Dataset: 0

# %%
train_data.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean      12.318813    145.419377    148.500273    151.247714    153.546531
# std        7.287552     41.358555     39.942152     39.056286     38.595247
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000    121.000000    126.000000    130.000000    133.000000
# 50%       13.000000    150.000000    153.000000    156.000000    158.000000
# 75%       19.000000    174.000000    176.000000    178.000000    179.000000
# max       24.000000    255.000000    255.000000    255.000000    255.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     156.210891    158.411255    160.472154    162.339683    163.954799
# std       37.111165     36.125579     35.016392     33.661998     32.651607
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      137.000000    140.000000    142.000000    144.000000    146.000000
# 50%      160.000000    162.000000    164.000000    165.000000    166.000000
# 75%      181.000000    182.000000    183.000000    184.000000    185.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  27455.000000  27455.000000  27455.000000  27455.000000
# mean   ...    141.104863    147.495611    153.325806    159.125332
# std    ...     63.751194     65.512894     64.427412     63.708507
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     92.000000     96.000000    103.000000    112.000000
# 50%    ...    144.000000    162.000000    172.000000    180.000000
# 75%    ...    196.000000    202.000000    205.000000    207.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     161.969259    162.736696    162.906137    161.966454    161.137898
# std       63.738316     63.444008     63.509210     63.298721     63.610415
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      120.000000    125.000000    128.000000    128.000000    128.000000
# 50%      183.000000    184.000000    184.000000    182.000000    182.000000
# 75%      208.000000    207.000000    207.000000    206.000000    204.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#            pixel784
# count  27455.000000
# mean     159.824731
# std       64.396846
# min        0.000000
# 25%      125.500000
# 50%      182.000000
# 75%      204.000000
# max      255.000000
#
# [8 rows x 785 columns]

# %%
train_data['label'].value_counts()
# Out:
# label
# 17    1294
# 16    1279
# 11    1241
# 22    1225
# 5     1204
# 18    1199
# 3     1196
# 14    1196
# 19    1186
# 23    1164
# 8     1162
# 20    1161
# 13    1151
# 2     1144
# 0     1126
# 24    1118
# 10    1114
# 6     1090
# 15    1088
# 21    1082
# 12    1055
# 7     1013
# 1     1010
# 4      957
# Name: count, dtype: int64

# %%
train_data.groupby('label').mean()
# Out:
#            pixel1      pixel2      pixel3      pixel4      pixel5      pixel6  \
# label
# 0      164.192718  165.654529  162.869449  161.313499  164.491119  166.727353
# 1      145.215842  147.747525  150.145545  152.939604  153.605941  156.361386
# 2      160.759615  163.133741  165.435315  167.272727  168.677448  169.820804
# 3      135.755853  139.376254  143.024247  148.172241  152.219900  155.625418
# 4      165.823406  167.623824  169.475444  171.073145  172.587252  173.821317
# 5      142.225914  146.210963  149.949336  153.074751  156.021595  158.924419
# 6      172.902752  174.281651  175.629358  177.147706  178.300917  179.241284
# 7      164.142152  166.440276  168.638697  170.805528  172.312932  173.537019
# 8      158.496558  160.747849  163.317556  165.046472  166.765921  168.179862
# 10      98.201077  105.070916  106.421903  106.517056  110.669659  113.529623
# 11     145.435939  149.220790  152.510878  155.198227  157.369057  159.535858
# 12     154.750711  157.974408  161.098578  163.578199  166.026540  168.459716
# 13     157.411816  160.854040  163.759340  166.374457  169.079930  171.147698
# 14     161.355351  163.436455  165.187291  166.747492  168.029264  169.086957
# 15     112.225184  110.930147  114.314338  114.817096  119.392463  121.142463
# 16     117.048475  120.875684  125.842064  128.617670  131.820172  136.143862
# 17     134.270479  138.169243  142.313756  146.035549  149.309892  152.119011
# 18     151.948290  154.548791  156.869892  159.437031  161.964971  164.391159
# 19     166.867622  168.720067  170.643339  172.256324  173.516020  174.434233
# 20     132.024117  135.395349  138.642550  140.480620  144.547804  147.639104
# 21     142.470425  147.283734  151.431608  155.033272  158.054529  160.722736
# 22     123.885714  128.200816  132.508571  136.757551  141.649796  143.020408
# 23     146.842784  151.432990  154.707045  157.286942  159.776632  161.934708
# 24     145.576029  149.663685  153.299642  156.482111  159.526834  162.500000
#
#            pixel7      pixel8      pixel9     pixel10  ...    pixel775  \
# label                                                  ...
# 0      167.836590  168.973357  170.000888  170.912078  ...  150.468028
# 1      158.268317  159.686139  161.683168  163.297030  ...  115.632673
# 2      170.624126  171.098776  171.569056  171.852273  ...  204.282343
# 3      158.278428  160.520067  162.428930  163.739130  ...  111.417224
# 4      174.794148  175.515152  176.350052  177.073145  ...  108.669801
# 5      161.091362  162.809801  164.390365  165.755814  ...  160.012458
# 6      179.950459  180.405505  180.885321  181.056881  ...  140.392661
# 7      174.420533  175.444225  176.389931  177.032577  ...  158.322804
# 8      169.482788  170.104131  170.869191  170.419105  ...  152.191910
# 10     116.983842  120.732496  124.865350  129.729803  ...  123.717235
# 11     161.359388  162.684126  164.033038  165.149879  ...  166.525383
# 12     170.395261  171.813270  173.102370  174.359242  ...  127.462559
# 13     173.033884  174.928758  176.480452  177.688966  ...  129.013032
# 14     170.295151  171.518395  172.285953  172.626254  ...  177.392140
# 15     123.653493  126.052390  127.333640  133.009191  ...  111.076287
# 16     139.783425  143.946052  147.946833  151.464425  ...  110.453479
# 17     154.632921  156.761978  158.636785  160.319165  ...  123.179289
# 18     166.617181  168.483736  170.252711  171.694746  ...  125.713094
# 19     175.309444  176.000000  176.607926  177.109612  ...  182.552277
# 20     150.905254  153.603790  156.252369  158.413437  ...  130.627046
# 21     163.420518  165.555453  166.512939  168.001848  ...  136.813309
# 22     146.920816  151.552653  153.942857  157.066122  ...  125.595918
# 23     164.047251  165.969931  167.768900  169.163230  ...  157.018041
# 24     164.762075  166.785331  168.593918  169.915027  ...  151.415921
#
#          pixel776    pixel777    pixel778    pixel779    pixel780    pixel781  \
# label
# 0      160.253108  176.450266  187.197158  188.055062  184.572824  182.956483
# 1      141.738614  148.600000  147.710891  147.746535  147.806931  147.411881
# 2      203.943182  203.489510  205.226399  204.839161  203.986014  203.624126
# 3      121.210702  134.167224  142.347826  142.612040  143.934783  145.229933
# 4      133.425287  151.493208  167.268548  177.102403  179.031348  177.304075
# 5      167.903654  172.402824  173.190199  173.875415  172.589701  171.991694
# 6      139.537615  141.325688  139.804587  138.225688  138.670642  137.563303
# 7      156.843040  153.355380  158.425469  157.021718  155.765054  154.955577
# 8      155.416523  163.645439  168.731497  167.242685  168.965577  170.728055
# 10     130.871634  137.146320  153.196589  165.406643  168.403950  166.958707
# 11     166.470588  166.120870  163.533441  165.517325  163.265915  163.535858
# 12     142.200000  153.345024  168.071090  172.173460  176.144076  180.167773
# 13     141.893136  157.148566  163.778454  165.526499  166.478714  163.953953
# 14     183.171405  185.826087  188.119565  187.289298  185.918060  183.944816
# 15     102.850184  101.602022   98.954044   96.488971   98.402574   95.988971
# 16     114.537138  118.733385  125.266615  128.323690  126.107897  133.818608
# 17     130.818393  138.285935  147.193972  158.482998  160.534776  160.361669
# 18     135.495413  145.462886  156.315263  161.597164  167.109258  171.265221
# 19     180.316189  177.265599  178.801012  178.994941  177.290051  173.265599
# 20     135.850991  151.136090  166.369509  168.658915  173.868217  176.882860
# 21     148.534196  149.146950  157.582255  168.319778  166.513863  161.125693
# 22     130.168980  132.414694  139.655510  151.383673  155.827755  158.150204
# 23     160.934708  162.574742  161.984536  161.033505  161.402062  161.185567
# 24     154.018784  158.593918  161.643113  162.086762  164.023256  166.616279
#
#          pixel782    pixel783    pixel784
# label
# 0      182.216696  178.341918  174.761989
# 1      146.214851  141.502970  135.559406
# 2      203.402972  202.751748  198.966783
# 3      143.940635  144.337793  139.172241
# 4      174.777429  174.463950  176.704284
# 5      170.939369  168.640365  168.648671
# 6      132.542202  133.037615  130.490826
# 7      146.279368  140.607108  141.894373
# 8      168.012909  162.453528  158.351119
# 10     166.259425  166.642729  165.253142
# 11     161.701048  162.967768  163.932313
# 12     177.163981  179.260664  177.495735
# 13     165.503910  167.137272  163.814075
# 14     182.204849  178.677258  174.612876
# 15     102.294118  111.190257  118.699449
# 16     143.493354  145.188428  143.525410
# 17     160.171561  158.336167  158.412674
# 18     171.310259  170.286906  170.804837
# 19     170.405565  169.347386  166.630691
# 20     174.746770  172.584841  171.611542
# 21     158.651571  155.836414  151.692237
# 22     155.568163  154.617959  151.715102
# 23     162.793814  166.455326  169.615979
# 24     163.449911  158.954383  160.227191
#
# [24 rows x 784 columns]

# %%
#creating a duplicate dataframe and filling missing values
train_df_filled = train_data.copy()
train_df_filled.iloc[:,1:] = train_data.groupby('label').transform(lambda x: x.fillna(x.mean()))

# %%
train_df_filled.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Count the number of samples for each label
plt.figure(figsize=(12,6))
sns.countplot(x=train_df_filled['label'], palette='viridis')

plt.title("Class Distribution of ASL data in Training Dataset")
plt.xlabel("ASL Alphabet(label)")
plt.ylabel("Number of images")
plt.xticks(rotation=0)

plt.show()
# Out:
# <ipython-input-13-3f66bd4f67c3>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=train_df_filled['label'], palette='viridis')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Extract Label and pixel values
labels = train_df_filled['label'].values
images = train_df_filled.iloc[:,1:].values

#Reshape few images to 28x28
images = images.reshape(-1, 28, 28)

#Plot some sample images
fig, axes = plt.subplots(5,5, figsize=(12,6))
axes = axes.ravel()


for i in range(25):
  axes[i].imshow(images[i], cmap='gray')
  axes[i].set_title(f"label: {labels[i]}")
  axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
#Plotting Pixel Intensity Histogram
import numpy as np
import matplotlib.pyplot as plt

#Flatten all pixel values into a single array
pixel_data = train_df_filled.iloc[:, 1:].values.flatten()

#Plot histogram of Pixel intensity
plt.figure(figsize=(10,5))
plt.hist(pixel_data, bins=50, color='skyblue', alpha=0.7, edgecolor='black')
plt.title('Pixel Intensity Distribution')
plt.xlabel("Pixel Intensity (0-255)")
plt.ylabel("Frequencey")
plt.show()

# %%
#Plotting heatmap of pixel correlation
import seaborn as sns

#Computing correlation matrix for small number of pixel
corr_matrix = train_df_filled.iloc[:,1:50].corr()

#Plot the heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False, linewidths=0.5)
plt.title("Pixel Correlation Heatmap")
plt.show()

# %%
# Compute pixel variance for the entire dataset
pixel_variances = train_df_filled.iloc[:, 1:].var().values.reshape(28, 28)

# Plot the heatmap
plt.figure(figsize=(5, 5))
plt.imshow(pixel_variances, cmap="magma")
plt.title("Pixel Intensity Variance Heatmap")
plt.colorbar(label="Variance")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Randomly selecting 5 images from the dataset
random_indices = np.random.choice(len(images), 5,  replace = False)
sample_images = images[random_indices]

#Plot the original and edge-detected image
fig, axes = plt.subplots(5,4, figsize=(15,15))

for i, img in enumerate(sample_images):
  img=np.uint8(img)
  sobelx = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize=5)
  sobely = cv2.Sobel(img, cv2.CV_64F, 0,1, ksize=5)

  canny_edges= cv2.Canny(np.uint8(img), 50, 150)

  axes[i,0].imshow(img, cmap='gray')
  axes[i,0].set_title("Original Image")
  axes[i,1].imshow(sobelx, cmap='gray')
  axes[i,1].set_title("Sobel X")
  axes[i,2].imshow(sobely, cmap='gray')
  axes[i,2].set_title("Sobel Y")
  axes[i,3].imshow(canny_edges, cmap='gray')
  axes[i,3].set_title("Canny Edges")

  for ax in axes[i]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
#Statistical summary
pixel_stats= train_df_filled.iloc[:,1:].describe().T

pixel_stats.head()
# Out:
#           count        mean        std  min    25%    50%    75%    max
# pixel1  27455.0  145.419377  41.358555  0.0  121.0  150.0  174.0  255.0
# pixel2  27455.0  148.500273  39.942152  0.0  126.0  153.0  176.0  255.0
# pixel3  27455.0  151.247714  39.056286  0.0  130.0  156.0  178.0  255.0
# pixel4  27455.0  153.546531  38.595247  0.0  133.0  158.0  179.0  255.0
# pixel5  27455.0  156.210891  37.111165  0.0  137.0  160.0  181.0  255.0

# %%
#Normalizing the data
train_df_normalized = train_df_filled.copy()
train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:]/255.0

print("After Normalization : ")
print("Min Pixel value : ", train_df_normalized.iloc[:,1:].min().min())
print("Max Pixel value : ", train_df_normalized.iloc[:,1:].max().max())
# Out:
# Streaming output truncated to the last 5000 lines.
#          ...
# 27450    181.0
# 27451    202.0
# 27452    149.0
# 27453    218.0
# 27454    215.0
# Name: pixel400, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        189.0
# 1        135.0
# 2        105.0
# 3        208.0
# 4        202.0
#          ...
# 27450    138.0
# 27451    202.0
# 27452    113.0
# 27453    216.0
# 27454    207.0
# Name: pixel401, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        165.0
# 1        134.0
# 2         82.0
# 3        181.0
# 4        180.0
#          ...
# 27450    177.0
# 27451    201.0
# 27452    104.0
# 27453    223.0
# 27454    181.0
# Name: pixel402, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        151.0
# 1        130.0
# 2         79.0
# 3        132.0
# 4        159.0
#          ...
# 27450    168.0
# 27451    161.0
# 27452     93.0
# 27453    243.0
# 27454    150.0
# Name: pixel403, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        143.0
# 1        137.0
# 2         80.0
# 3        101.0
# 4        133.0
#          ...
# 27450    142.0
# 27451    141.0
# 27452     74.0
# 27453    203.0
# 27454    182.0
# Name: pixel404, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        146.0
# 1        146.0
# 2         75.0
# 3         82.0
# 4        116.0
#          ...
# 27450     89.0
# 27451    135.0
# 27452    107.0
# 27453    182.0
# 27454    184.0
# Name: pixel405, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        120.0
# 1        147.0
# 2        129.0
# 3         58.0
# 4        111.0
#          ...
# 27450     35.0
# 27451    127.0
# 27452    111.0
# 27453    162.0
# 27454    172.0
# Name: pixel406, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         87.0
# 1        164.0
# 2        206.0
# 3        131.0
# 4         70.0
#          ...
# 27450    172.0
# 27451    166.0
# 27452     81.0
# 27453    145.0
# 27454    159.0
# Name: pixel407, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         78.0
# 1        165.0
# 2        198.0
# 3        237.0
# 4        149.0
#          ...
# 27450    209.0
# 27451    151.0
# 27452     75.0
# 27453    147.0
# 27454    140.0
# Name: pixel408, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         87.0
# 1        147.0
# 2        199.0
# 3        219.0
# 4        183.0
#          ...
# 27450    171.0
# 27451    131.0
# 27452     90.0
# 27453    120.0
# 27454    107.0
# Name: pixel409, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         76.0
# 1        103.0
# 2        198.0
# 3        222.0
# 4        204.0
#          ...
# 27450    129.0
# 27451     89.0
# 27452    106.0
# 27453    221.0
# 27454    119.0
# Name: pixel410, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        108.0
# 1        151.0
# 2        197.0
# 3        222.0
# 4        193.0
#          ...
# 27450     38.0
# 27451     75.0
# 27452    123.0
# 27453    255.0
# 27454     70.0
# Name: pixel411, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         98.0
# 1        182.0
# 2        196.0
# 3        220.0
# 4        170.0
#          ...
# 27450     96.0
# 27451     78.0
# 27452    158.0
# 27453    196.0
# 27454     45.0
# Name: pixel412, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         96.0
# 1        176.0
# 2        196.0
# 3        217.0
# 4        143.0
#          ...
# 27450    202.0
# 27451    105.0
# 27452    179.0
# 27453    115.0
# 27454     78.0
# Name: pixel413, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        181.0
# 1        176.0
# 2        194.0
# 3        216.0
# 4        110.0
#          ...
# 27450    207.0
# 27451    121.0
# 27452    155.0
# 27453    187.0
# 27454     62.0
# Name: pixel414, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        188.0
# 1        175.0
# 2        193.0
# 3        216.0
# 4         89.0
#          ...
# 27450    205.0
# 27451    187.0
# 27452    107.0
# 27453    219.0
# 27454    151.0
# Name: pixel415, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        187.0
# 1        173.0
# 2        192.0
# 3        215.0
# 4         93.0
#          ...
# 27450    169.0
# 27451    188.0
# 27452    115.0
# 27453    211.0
# 27454    206.0
# Name: pixel416, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        186.0
# 1        172.0
# 2        190.0
# 3        208.0
# 4        192.0
#          ...
# 27450    144.0
# 27451    184.0
# 27452    179.0
# 27453    211.0
# 27454    193.0
# Name: pixel417, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        186.0
# 1        170.0
# 2        189.0
# 3        182.0
# 4        213.0
#          ...
# 27450     92.0
# 27451    186.0
# 27452    187.0
# 27453    208.0
# 27454    194.0
# Name: pixel418, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        185.0
# 1        167.0
# 2        184.0
# 3        184.0
# 4        211.0
#          ...
# 27450    141.0
# 27451    185.0
# 27452    185.0
# 27453    207.0
# 27454    194.0
# Name: pixel419, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        183.0
# 1        166.0
# 2        166.0
# 3        167.0
# 4        211.0
#          ...
# 27450    219.0
# 27451    184.0
# 27452    184.0
# 27453    205.0
# 27454    194.0
# Name: pixel420, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        133.0
# 1        184.0
# 2        204.0
# 3        235.0
# 4        181.0
#          ...
# 27450    194.0
# 27451    168.0
# 27452    204.0
# 27453    204.0
# 27454    195.0
# Name: pixel421, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        141.0
# 1        185.0
# 2        204.0
# 3        236.0
# 4        184.0
#          ...
# 27450    197.0
# 27451    172.0
# 27452    203.0
# 27453    208.0
# 27454    196.0
# Name: pixel422, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        150.0
# 1        185.0
# 2        207.0
# 3        234.0
# 4        187.0
#          ...
# 27450    198.0
# 27451    176.0
# 27452    203.0
# 27453    211.0
# 27454    198.0
# Name: pixel423, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        156.0
# 1        176.0
# 2        202.0
# 3        226.0
# 4        190.0
#          ...
# 27450    199.0
# 27451    177.0
# 27452    202.0
# 27453    211.0
# 27454    200.0
# Name: pixel424, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        160.0
# 1        174.0
# 2        234.0
# 3        250.0
# 4        194.0
#          ...
# 27450    196.0
# 27451    180.0
# 27452    199.0
# 27453    214.0
# 27454    196.0
# Name: pixel425, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        161.0
# 1        163.0
# 2        228.0
# 3        250.0
# 4        196.0
#          ...
# 27450    207.0
# 27451    176.0
# 27452    197.0
# 27453    216.0
# 27454    206.0
# Name: pixel426, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        179.0
# 1        147.0
# 2        186.0
# 3        230.0
# 4        200.0
#          ...
# 27450    222.0
# 27451    199.0
# 27452    180.0
# 27453    218.0
# 27454    224.0
# Name: pixel427, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        197.0
# 1        145.0
# 2        141.0
# 3        218.0
# 4        214.0
#          ...
# 27450    204.0
# 27451    210.0
# 27452    150.0
# 27453    219.0
# 27454    216.0
# Name: pixel428, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        174.0
# 1        142.0
# 2         97.0
# 3        201.0
# 4        203.0
#          ...
# 27450    160.0
# 27451    198.0
# 27452    115.0
# 27453    217.0
# 27454    201.0
# Name: pixel429, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        135.0
# 1        141.0
# 2         80.0
# 3        162.0
# 4        183.0
#          ...
# 27450    155.0
# 27451    184.0
# 27452     81.0
# 27453    228.0
# 27454    158.0
# Name: pixel430, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         99.0
# 1        141.0
# 2         80.0
# 3        124.0
# 4        166.0
#          ...
# 27450    180.0
# 27451    151.0
# 27452     61.0
# 27453    255.0
# 27454    119.0
# Name: pixel431, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         72.0
# 1        133.0
# 2         79.0
# 3         93.0
# 4        149.0
#          ...
# 27450    146.0
# 27451    112.0
# 27452     52.0
# 27453    226.0
# 27454    124.0
# Name: pixel432, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         95.0
# 1        125.0
# 2         68.0
# 3         62.0
# 4        119.0
#          ...
# 27450    146.0
# 27451    101.0
# 27452     78.0
# 27453    184.0
# 27454    177.0
# Name: pixel433, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        134.0
# 1        125.0
# 2        136.0
# 3         82.0
# 4        104.0
#          ...
# 27450     74.0
# 27451     87.0
# 27452     86.0
# 27453    167.0
# 27454    167.0
# Name: pixel434, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         97.0
# 1        135.0
# 2        209.0
# 3        214.0
# 4        109.0
#          ...
# 27450     36.0
# 27451    115.0
# 27452     66.0
# 27453    170.0
# 27454    153.0
# Name: pixel435, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         72.0
# 1        135.0
# 2        198.0
# 3        228.0
# 4        188.0
#          ...
# 27450    187.0
# 27451    181.0
# 27452     86.0
# 27453    179.0
# 27454    141.0
# Name: pixel436, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         74.0
# 1        112.0
# 2        199.0
# 3        223.0
# 4        205.0
#          ...
# 27450    198.0
# 27451    136.0
# 27452    129.0
# 27453    165.0
# 27454     79.0
# Name: pixel437, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         68.0
# 1        105.0
# 2        199.0
# 3        224.0
# 4        209.0
#          ...
# 27450    172.0
# 27451     79.0
# 27452    164.0
# 27453    222.0
# 27454     98.0
# Name: pixel438, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        116.0
# 1        181.0
# 2        198.0
# 3        225.0
# 4        189.0
#          ...
# 27450    134.0
# 27451     72.0
# 27452    171.0
# 27453    255.0
# 27454     85.0
# Name: pixel439, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        105.0
# 1        179.0
# 2        197.0
# 3        223.0
# 4        160.0
#          ...
# 27450    119.0
# 27451     78.0
# 27452    167.0
# 27453    214.0
# 27454     41.0
# Name: pixel440, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        108.0
# 1        176.0
# 2        198.0
# 3        219.0
# 4        133.0
#          ...
# 27450    223.0
# 27451    105.0
# 27452    167.0
# 27453    131.0
# 27454     71.0
# Name: pixel441, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        187.0
# 1        177.0
# 2        197.0
# 3        217.0
# 4        102.0
#          ...
# 27450    206.0
# 27451     80.0
# 27452    149.0
# 27453    180.0
# 27454     78.0
# Name: pixel442, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        189.0
# 1        175.0
# 2        196.0
# 3        216.0
# 4         85.0
#          ...
# 27450    180.0
# 27451     96.0
# 27452    102.0
# 27453    223.0
# 27454    186.0
# Name: pixel443, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        187.0
# 1        174.0
# 2        192.0
# 3        215.0
# 4        108.0
#          ...
# 27450    142.0
# 27451    189.0
# 27452    111.0
# 27453    212.0
# 27454    200.0
# Name: pixel444, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        187.0
# 1        173.0
# 2        192.0
# 3        214.0
# 4        206.0
#          ...
# 27450    127.0
# 27451    187.0
# 27452    179.0
# 27453    212.0
# 27454    196.0
# Name: pixel445, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        186.0
# 1        171.0
# 2        191.0
# 3        196.0
# 4        213.0
#          ...
# 27450     79.0
# 27451    187.0
# 27452    188.0
# 27453    213.0
# 27454    195.0
# Name: pixel446, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        186.0
# 1        169.0
# 2        190.0
# 3        174.0
# 4        213.0
#          ...
# 27450    153.0
# 27451    185.0
# 27452    186.0
# 27453    215.0
# 27454    194.0
# Name: pixel447, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        185.0
# 1        166.0
# 2        158.0
# 3        181.0
# 4        212.0
#          ...
# 27450    217.0
# 27451    185.0
# 27452    185.0
# 27453    213.0
# 27454    195.0
# Name: pixel448, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        134.0
# 1        185.0
# 2        206.0
# 3        235.0
# 4        182.0
#          ...
# 27450    193.0
# 27451    169.0
# 27452    206.0
# 27453    205.0
# 27454    195.0
# Name: pixel449, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        143.0
# 1        186.0
# 2        206.0
# 3        237.0
# 4        185.0
#          ...
# 27450    195.0
# 27451    172.0
# 27452    205.0
# 27453    208.0
# 27454    195.0
# Name: pixel450, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        151.0
# 1        182.0
# 2        202.0
# 3        233.0
# 4        188.0
#          ...
# 27450    196.0
# 27451    176.0
# 27452    204.0
# 27453    210.0
# 27454    196.0
# Name: pixel451, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        156.0
# 1        170.0
# 2        215.0
# 3        248.0
# 4        191.0
#          ...
# 27450    197.0
# 27451    179.0
# 27452    204.0
# 27453    213.0
# 27454    198.0
# Name: pixel452, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        161.0
# 1        161.0
# 2        240.0
# 3        255.0
# 4        194.0
#          ...
# 27450    195.0
# 27451    177.0
# 27452    199.0
# 27453    215.0
# 27454    194.0
# Name: pixel453, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        163.0
# 1        132.0
# 2        217.0
# 3        244.0
# 4        196.0
#          ...
# 27450    205.0
# 27451    192.0
# 27452    200.0
# 27453    216.0
# 27454    209.0
# Name: pixel454, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        179.0
# 1        125.0
# 2        174.0
# 3        222.0
# 4        200.0
#          ...
# 27450    216.0
# 27451    213.0
# 27452    192.0
# 27453    218.0
# 27454    225.0
# Name: pixel455, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        194.0
# 1        134.0
# 2        130.0
# 3        209.0
# 4        211.0
#          ...
# 27450    199.0
# 27451    208.0
# 27452    169.0
# 27453    219.0
# 27454    229.0
# Name: pixel456, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        156.0
# 1        130.0
# 2         91.0
# 3        182.0
# 4        203.0
#          ...
# 27450    178.0
# 27451    189.0
# 27452    135.0
# 27453    217.0
# 27454    191.0
# Name: pixel457, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        110.0
# 1        144.0
# 2         78.0
# 3        148.0
# 4        185.0
#          ...
# 27450    146.0
# 27451    169.0
# 27452     93.0
# 27453    230.0
# 27454    116.0
# Name: pixel458, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         74.0
# 1        157.0
# 2         74.0
# 3        116.0
# 4        171.0
#          ...
# 27450    146.0
# 27451    160.0
# 27452     67.0
# 27453    254.0
# 27454     92.0
# Name: pixel459, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         42.0
# 1        159.0
# 2         71.0
# 3         82.0
# 4        164.0
#          ...
# 27450    174.0
# 27451    124.0
# 27452     60.0
# 27453    200.0
# 27454     70.0
# Name: pixel460, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         52.0
# 1        152.0
# 2         70.0
# 3         50.0
# 4        140.0
#          ...
# 27450    170.0
# 27451     81.0
# 27452     67.0
# 27453    174.0
# 27454    108.0
# Name: pixel461, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        139.0
# 1        141.0
# 2         83.0
# 3        126.0
# 4        122.0
#          ...
# 27450    130.0
# 27451     81.0
# 27452     79.0
# 27453    178.0
# 27454    151.0
# Name: pixel462, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         94.0
# 1        132.0
# 2        192.0
# 3        246.0
# 4        127.0
#          ...
# 27450     46.0
# 27451    154.0
# 27452     98.0
# 27453    196.0
# 27454    132.0
# Name: pixel463, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         67.0
# 1        121.0
# 2        203.0
# 3        222.0
# 4        187.0
#          ...
# 27450     53.0
# 27451    188.0
# 27452    142.0
# 27453    197.0
# 27454     95.0
# Name: pixel464, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         75.0
# 1         72.0
# 2        200.0
# 3        226.0
# 4        206.0
#          ...
# 27450    189.0
# 27451    113.0
# 27452    177.0
# 27453    220.0
# 27454     65.0
# Name: pixel465, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         75.0
# 1        142.0
# 2        200.0
# 3        226.0
# 4        201.0
#          ...
# 27450    193.0
# 27451     79.0
# 27452    187.0
# 27453    255.0
# 27454    107.0
# Name: pixel466, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        118.0
# 1        176.0
# 2        201.0
# 3        226.0
# 4        173.0
#          ...
# 27450    184.0
# 27451     67.0
# 27452    176.0
# 27453    251.0
# 27454     87.0
# Name: pixel467, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        106.0
# 1        175.0
# 2        200.0
# 3        225.0
# 4        142.0
#          ...
# 27450    158.0
# 27451     77.0
# 27452    160.0
# 27453    218.0
# 27454     49.0
# Name: pixel468, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        129.0
# 1        182.0
# 2        191.0
# 3        219.0
# 4        119.0
#          ...
# 27450    209.0
# 27451     93.0
# 27452    142.0
# 27453    144.0
# 27454     63.0
# Name: pixel469, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        189.0
# 1        177.0
# 2        177.0
# 3        219.0
# 4         95.0
#          ...
# 27450    192.0
# 27451     77.0
# 27452    121.0
# 27453    174.0
# 27454    129.0
# Name: pixel470, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        191.0
# 1        177.0
# 2        164.0
# 3        222.0
# 4         85.0
#          ...
# 27450    166.0
# 27451     53.0
# 27452     87.0
# 27453    226.0
# 27454    208.0
# Name: pixel471, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        190.0
# 1        177.0
# 2        151.0
# 3        213.0
# 4        147.0
#          ...
# 27450    124.0
# 27451    139.0
# 27452    114.0
# 27453    213.0
# 27454    196.0
# Name: pixel472, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        188.0
# 1        175.0
# 2        144.0
# 3        213.0
# 4        214.0
#          ...
# 27450     90.0
# 27451    198.0
# 27452    181.0
# 27453    217.0
# 27454    198.0
# Name: pixel473, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        188.0
# 1        172.0
# 2        164.0
# 3        217.0
# 4        214.0
#          ...
# 27450     67.0
# 27451    186.0
# 27452    189.0
# 27453    208.0
# 27454    197.0
# Name: pixel474, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        187.0
# 1        169.0
# 2        190.0
# 3        180.0
# 4        215.0
#          ...
# 27450    180.0
# 27451    186.0
# 27452    188.0
# 27453    187.0
# 27454    196.0
# Name: pixel475, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        186.0
# 1        168.0
# 2        187.0
# 3        122.0
# 4        214.0
#          ...
# 27450    212.0
# 27451    185.0
# 27452    186.0
# 27453    179.0
# 27454    195.0
# Name: pixel476, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        135.0
# 1        186.0
# 2        206.0
# 3        237.0
# 4        181.0
#          ...
# 27450    198.0
# 27451    171.0
# 27452    207.0
# 27453    205.0
# 27454    195.0
# Name: pixel477, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        144.0
# 1        186.0
# 2        207.0
# 3        234.0
# 4        185.0
#          ...
# 27450    200.0
# 27451    173.0
# 27452    206.0
# 27453    208.0
# 27454    195.0
# Name: pixel478, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        152.0
# 1        173.0
# 2        199.0
# 3        245.0
# 4        187.0
#          ...
# 27450    204.0
# 27451    176.0
# 27452    206.0
# 27453    210.0
# 27454    196.0
# Name: pixel479, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        158.0
# 1        168.0
# 2        229.0
# 3        255.0
# 4        190.0
#          ...
# 27450    205.0
# 27451    178.0
# 27452    206.0
# 27453    212.0
# 27454    198.0
# Name: pixel480, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        163.0
# 1        159.0
# 2        234.0
# 3        252.0
# 4        193.0
#          ...
# 27450    203.0
# 27451    184.0
# 27452    201.0
# 27453    215.0
# 27454    194.0
# Name: pixel481, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        163.0
# 1        128.0
# 2        204.0
# 3        232.0
# 4        196.0
#          ...
# 27450    206.0
# 27451    214.0
# 27452    201.0
# 27453    216.0
# 27454    215.0
# Name: pixel482, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        177.0
# 1        115.0
# 2        160.0
# 3        212.0
# 4        199.0
#          ...
# 27450    221.0
# 27451    212.0
# 27452    199.0
# 27453    216.0
# 27454    231.0
# Name: pixel483, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        193.0
# 1        119.0
# 2        119.0
# 3        198.0
# 4        204.0
#          ...
# 27450    223.0
# 27451    198.0
# 27452    179.0
# 27453    218.0
# 27454    221.0
# Name: pixel484, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        161.0
# 1        109.0
# 2         89.0
# 3        171.0
# 4        200.0
#          ...
# 27450    201.0
# 27451    178.0
# 27452    147.0
# 27453    217.0
# 27454    185.0
# Name: pixel485, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        122.0
# 1        111.0
# 2         75.0
# 3        129.0
# 4        190.0
#          ...
# 27450    173.0
# 27451    172.0
# 27452    108.0
# 27453    228.0
# 27454    126.0
# Name: pixel486, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         84.0
# 1        140.0
# 2         66.0
# 3         98.0
# 4        176.0
#          ...
# 27450    139.0
# 27451    151.0
# 27452     82.0
# 27453    255.0
# 27454     78.0
# Name: pixel487, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         43.0
# 1        154.0
# 2         69.0
# 3         66.0
# 4        169.0
#          ...
# 27450    146.0
# 27451    113.0
# 27452     82.0
# 27453    225.0
# 27454     27.0
# Name: pixel488, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         71.0
# 1        156.0
# 2         73.0
# 3         66.0
# 4        148.0
#          ...
# 27450    169.0
# 27451     82.0
# 27452     99.0
# 27453    195.0
# 27454    110.0
# ...
# 2        194.0
# 3        220.0
# 4        156.0
#          ...
# 27450    219.0
# 27451    195.0
# 27452    200.0
# 27453    100.0
# 27454    213.0
# Name: pixel755, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        202.0
# 1        120.0
# 2        193.0
# 3        216.0
# 4        179.0
#          ...
# 27450    208.0
# 27451    194.0
# 27452    198.0
# 27453     86.0
# 27454    215.0
# Name: pixel756, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        142.0
# 1        135.0
# 2        198.0
# 3         58.0
# 4        105.0
#          ...
# 27450     82.0
# 27451     66.0
# 27452    217.0
# 27453    136.0
# 27454     96.0
# Name: pixel757, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        151.0
# 1        116.0
# 2        166.0
# 3         51.0
# 4        106.0
#          ...
# 27450     82.0
# 27451     67.0
# 27452    217.0
# 27453    135.0
# 27454     88.0
# Name: pixel758, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        160.0
# 1         95.0
# 2        132.0
# 3         49.0
# 4        105.0
#          ...
# 27450     84.0
# 27451     65.0
# 27452    217.0
# 27453    135.0
# 27454    109.0
# Name: pixel759, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        172.0
# 1         79.0
# 2        114.0
# 3         50.0
# 4        104.0
#          ...
# 27450     85.0
# 27451     62.0
# 27452    218.0
# 27453    135.0
# 27454    216.0
# Name: pixel760, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        196.0
# 1         69.0
# 2         89.0
# 3         57.0
# 4        104.0
#          ...
# 27450     85.0
# 27451     61.0
# 27452    218.0
# 27453    132.0
# 27454    208.0
# Name: pixel761, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        188.0
# 1         86.0
# 2         74.0
# 3         60.0
# 4        104.0
#          ...
# 27450     87.0
# 27451     41.0
# 27452    211.0
# 27453    132.0
# 27454    207.0
# Name: pixel762, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        188.0
# 1        139.0
# 2         79.0
# 3         17.0
# 4        175.0
#          ...
# 27450     84.0
# 27451     32.0
# 27452    203.0
# 27453    136.0
# 27454    203.0
# Name: pixel763, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        190.0
# 1        173.0
# 2         77.0
# 3         15.0
# 4        199.0
#          ...
# 27450     87.0
# 27451     37.0
# 27452    200.0
# 27453    136.0
# 27454    178.0
# Name: pixel764, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        135.0
# 1        200.0
# 2         74.0
# 3         18.0
# 4        178.0
#          ...
# 27450     78.0
# 27451     33.0
# 27452    189.0
# 27453    137.0
# 27454    151.0
# Name: pixel765, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         96.0
# 1        185.0
# 2         78.0
# 3         17.0
# 4        152.0
#          ...
# 27450    113.0
# 27451     30.0
# 27452    171.0
# 27453    144.0
# 27454    112.0
# Name: pixel766, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         86.0
# 1        175.0
# 2        132.0
# 3         19.0
# 4        136.0
#          ...
# 27450    216.0
# 27451     28.0
# 27452    157.0
# 27453    103.0
# 27454     87.0
# Name: pixel767, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         77.0
# 1        198.0
# 2        188.0
# 3          1.0
# 4        130.0
#          ...
# 27450    189.0
# 27451     38.0
# 27452    145.0
# 27453    120.0
# 27454     80.0
# Name: pixel768, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         77.0
# 1        124.0
# 2        210.0
# 3        159.0
# 4        136.0
#          ...
# 27450    172.0
# 27451    187.0
# 27452    136.0
# 27453    197.0
# 27454     76.0
# Name: pixel769, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0         79.0
# 1        118.0
# 2        209.0
# 3        255.0
# 4        150.0
#          ...
# 27450    175.0
# 27451    202.0
# 27452    129.0
# 27453    200.0
# 27454     80.0
# Name: pixel770, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        176.0
# 1         94.0
# 2        206.0
# 3        237.0
# 4        118.0
#          ...
# 27450    155.0
# 27451    199.0
# 27452    128.0
# 27453    195.0
# 27454     86.0
# Name: pixel771, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        205.0
# 1        140.0
# 2        205.0
# 3        239.0
# 4         92.0
#          ...
# 27450    131.0
# 27451    199.0
# 27452    125.0
# 27453    196.0
# 27454     97.0
# Name: pixel772, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1        133.0
# 2        204.0
# 3        237.0
# 4         85.0
#          ...
# 27450    116.0
# 27451    199.0
# 27452    101.0
# 27453    170.0
# 27454    102.0
# Name: pixel773, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1         84.0
# 2        203.0
# 3        236.0
# 4         76.0
#          ...
# 27450     93.0
# 27451    199.0
# 27452     77.0
# 27453    149.0
# 27454    103.0
# Name: pixel774, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1         69.0
# 2        202.0
# 3        235.0
# 4         92.0
#          ...
# 27450    132.0
# 27451    198.0
# 27452    121.0
# 27453    119.0
# 27454    108.0
# Name: pixel775, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1        149.0
# 2        201.0
# 3        234.0
# 4        105.0
#          ...
# 27450    165.0
# 27451    198.0
# 27452    196.0
# 27453     56.0
# 27454    132.0
# Name: pixel776, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1        128.0
# 2        200.0
# 3        233.0
# 4        105.0
#          ...
# 27450     99.0
# 27451    198.0
# 27452    209.0
# 27453     27.0
# 27454    170.0
# Name: pixel777, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        207.0
# 1         87.0
# 2        199.0
# 3        231.0
# 4        108.0
#          ...
# 27450     77.0
# 27451    198.0
# 27452    208.0
# 27453     58.0
# 27454    194.0
# Name: pixel778, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        206.0
# 1         94.0
# 2        198.0
# 3        230.0
# 4        133.0
#          ...
# 27450     52.0
# 27451    198.0
# 27452    206.0
# 27453    102.0
# 27454    214.0
# Name: pixel779, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        206.0
# 1        163.0
# 2        199.0
# 3        226.0
# 4        163.0
#          ...
# 27450    200.0
# 27451    196.0
# 27452    204.0
# 27453     79.0
# 27454    203.0
# Name: pixel780, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        206.0
# 1        175.0
# 2        198.0
# 3        225.0
# 4        157.0
#          ...
# 27450    234.0
# 27451    195.0
# 27452    203.0
# 27453     47.0
# 27454    197.0
# Name: pixel781, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        204.0
# 1        103.0
# 2        195.0
# 3        222.0
# 4        163.0
#          ...
# 27450    200.0
# 27451    195.0
# 27452    202.0
# 27453     64.0
# 27454    205.0
# Name: pixel782, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        203.0
# 1        135.0
# 2        194.0
# 3        229.0
# 4        164.0
#          ...
# 27450    222.0
# 27451    195.0
# 27452    200.0
# 27453     87.0
# 27454    209.0
# Name: pixel783, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# <ipython-input-20-cd47758c9784>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        202.0
# 1        149.0
# 2        195.0
# 3        163.0
# 4        179.0
#          ...
# 27450    225.0
# 27451    194.0
# 27452    200.0
# 27453     93.0
# 27454    215.0
# Name: pixel784, Length: 27455, dtype: float32' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df_normalized.iloc[:,1:] = train_df_normalized.iloc[:,1:].astype(np.float32)
# After Normalization :
# Min Pixel value :  0.0
# Max Pixel value :  1.0
